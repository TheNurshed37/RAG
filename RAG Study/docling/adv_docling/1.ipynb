# %%
import time
from docling.datamodel.base_models import InputFormat
from docling_core.types.doc import ImageRefMode
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.datamodel.pipeline_options import PdfPipelineOptions, TableFormerMode, EasyOcrOptions, TesseractOcrOptions, OcrMacOptions
from docling.datamodel.settings import settings
from pathlib import Path

# %%
output_dir = Path("/home/nurshed/Desktop/python/project/RAG Study/docling/adv_docling")

IMAGE_RESOLUTION_SCALE = 2.0

# Define pipeline options for PDF processing
pipeline_options = PdfPipelineOptions(
    do_table_structure=True,  # Enable table structure detection
    do_ocr=True,  # Enable OCR
    # full page ocr and language selection
    ocr_options=EasyOcrOptions(force_full_page_ocr=True, lang=["en"]),  # Use EasyOCR for OCR
    #ocr_options=TesseractOcrOptions(force_full_page_ocr=True, lang=["eng"]),  # Uncomment to use Tesseract for OCR
    #ocr_options = OcrMacOptions(force_full_page_ocr=True, lang=['en-US']),
    table_structure_options=dict(
        do_cell_matching=False,  # Use text cells predicted from table structure model
        mode=TableFormerMode.ACCURATE  # Use more accurate TableFormer model
    ),
    generate_page_images=True,  # Enable page image generation
    generate_picture_images=True,  # Enable picture image generation
    images_scale=IMAGE_RESOLUTION_SCALE, # Set image resolution scale (scale=1 corresponds to a standard 72 DPI image)
)

# Initialize the DocumentConverter with the specified pipeline options
doc_converter_global = DocumentConverter(
    format_options={
        InputFormat.PDF: PdfFormatOption(pipeline_options=pipeline_options)
    }
)

# %%
# Enable the profiling to measure the time spent
settings.debug.profile_pipeline_timings = True

# Convert the document
#result = doc_converter_global.convert(FIRST_10_PAGES)
#result = doc_converter_global.convert(SOURCE)
result = doc_converter_global.convert("/home/nurshed/Desktop/python/project/RAG Study/docling/cv_demo.pdf")

output_dir.mkdir(parents=True, exist_ok=True)
#doc_filename = Path(FIRST_10_PAGES).stem
#doc_filename = Path(FIRST_10_PAGES).stem
doc_filename = Path("/home/nurshed/Desktop/python/project/RAG Study/docling/cv_demo.pdf").stem

# Save markdown with embedded pictures
#md_filename = output_dir / f"{doc_filename}.md"
md_filename = output_dir / f"{doc_filename}-with-images.md"
#result.document.save_as_markdown(md_filename) # just shows there is image at this point, <!-- image -->
#result.document.save_as_markdown(md_filename, image_mode=ImageRefMode.EMBEDDED) # image is embedded with base64
result.document.save_as_markdown(md_filename, image_mode=ImageRefMode.REFERENCED) #artifacts folder is created with this

# _log.info(f"Markdown content has been saved to {md_filename}")
# Out:
# 2025-10-23 17:38:51,749 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-23 17:38:51,753 - INFO - Going to convert document batch...
# 2025-10-23 17:38:51,754 - INFO - Processing document cv_demo.pdf
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# 2025-10-23 17:40:49,518 - INFO - Finished converting document cv_demo.pdf in 117.77 sec.

# %%
# Enable the profiling to measure the time spent
settings.debug.profile_pipeline_timings = True

# Convert the document
#result = doc_converter_global.convert(FIRST_10_PAGES)
#result = doc_converter_global.convert(SOURCE)
result = doc_converter_global.convert("/home/nurshed/Desktop/python/project/RAG Study/docling/NIPS-2017-attention-is-all-you-need-Paper.pdf")

output_dir.mkdir(parents=True, exist_ok=True)
#doc_filename = Path(FIRST_10_PAGES).stem
#doc_filename = Path(FIRST_10_PAGES).stem
doc_filename = Path("/home/nurshed/Desktop/python/project/RAG Study/docling/NIPS-2017-attention-is-all-you-need-Paper.pdf").stem

# Save markdown with embedded pictures
#md_filename = output_dir / f"{doc_filename}.md"
md_filename = output_dir / f"{doc_filename}-with-images.md"
#result.document.save_as_markdown(md_filename) # just shows there is image at this point, <!-- image -->
#result.document.save_as_markdown(md_filename, image_mode=ImageRefMode.EMBEDDED) # image is embedded with base64
result.document.save_as_markdown(md_filename, image_mode=ImageRefMode.REFERENCED) #artifacts folder is created with this

_log.info(f"Markdown content has been saved to {md_filename}")
# Out:
# 2025-10-23 17:29:50,648 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-23 17:29:50,655 - INFO - Going to convert document batch...
# 2025-10-23 17:29:50,656 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 6722b4d67bf82aafc8858d5663f840fd
# 2025-10-23 17:29:50,658 - INFO - Accelerator device: 'cpu'
# 2025-10-23 17:29:53,224 - INFO - Accelerator device: 'cpu'
# 2025-10-23 17:29:55,023 - INFO - Accelerator device: 'cpu'
# 2025-10-23 17:29:56,036 - INFO - Processing document NIPS-2017-attention-is-all-you-need-Paper.pdf
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 7
#       2 settings.debug.profile_pipeline_timings = True
#       4 # Convert the document
#       5 #result = doc_converter_global.convert(FIRST_10_PAGES)
#       6 #result = doc_converter_global.convert(SOURCE)
# ----> 7 result = doc_converter_global.convert("/home/nurshed/Desktop/python/project/RAG Study/docling/NIPS-2017-attention-is-all-you-need-Paper.pdf")
#       9 output_dir.mkdir(parents=True, exist_ok=True)
#      10 #doc_filename = Path(FIRST_10_PAGES).stem
#      11 #doc_filename = Path(FIRST_10_PAGES).stem
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/pydantic/_internal/_validate_call.py:39, in update_wrapper_attributes.<locals>.wrapper_function(*args, **kwargs)
#      37 @functools.wraps(wrapped)
#      38 def wrapper_function(*args, **kwargs):
# ---> 39     return wrapper(*args, **kwargs)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/pydantic/_internal/_validate_call.py:136, in ValidateCallWrapper.__call__(self, *args, **kwargs)
#     133 if not self.__pydantic_complete__:
#     134     self._create_validators()
# --> 136 res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#     137 if self.__return_pydantic_validator__:
#     138     return self.__return_pydantic_validator__(res)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/document_converter.py:245, in DocumentConverter.convert(self, source, headers, raises_on_error, max_num_pages, max_file_size, page_range)
#     227 @validate_call(config=ConfigDict(strict=True))
#     228 def convert(
#     229     self,
#    (...)    235     page_range: PageRange = DEFAULT_PAGE_RANGE,
#     236 ) -> ConversionResult:
#     237     all_res = self.convert_all(
#     238         source=[source],
#     239         raises_on_error=raises_on_error,
#    (...)    243         page_range=page_range,
#     244     )
# --> 245     return next(all_res)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/document_converter.py:268, in DocumentConverter.convert_all(self, source, headers, raises_on_error, max_num_pages, max_file_size, page_range)
#     265 conv_res_iter = self._convert(conv_input, raises_on_error=raises_on_error)
#     267 had_result = False
# --> 268 for conv_res in conv_res_iter:
#     269     had_result = True
#     270     if raises_on_error and conv_res.status not in {
#     271         ConversionStatus.SUCCESS,
#     272         ConversionStatus.PARTIAL_SUCCESS,
#     273     }:
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/document_converter.py:340, in DocumentConverter._convert(self, conv_input, raises_on_error)
#     338             yield item
#     339 else:
# --> 340     for item in map(
#     341         process_func,
#     342         input_batch,
#     343     ):
#     344         elapsed = time.monotonic() - start_time
#     345         start_time = time.monotonic()
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/document_converter.py:387, in DocumentConverter._process_document(self, in_doc, raises_on_error)
#     383 valid = (
#     384     self.allowed_formats is not None and in_doc.format in self.allowed_formats
#     385 )
#     386 if valid:
# --> 387     conv_res = self._execute_pipeline(in_doc, raises_on_error=raises_on_error)
#     388 else:
#     389     error_message = f"File format not allowed: {in_doc.file}"
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/document_converter.py:410, in DocumentConverter._execute_pipeline(self, in_doc, raises_on_error)
#     408 pipeline = self._get_pipeline(in_doc.format)
#     409 if pipeline is not None:
# --> 410     conv_res = pipeline.execute(in_doc, raises_on_error=raises_on_error)
#     411 else:
#     412     if raises_on_error:
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/pipeline/base_pipeline.py:72, in BasePipeline.execute(self, in_doc, raises_on_error)
#      66 try:
#      67     with TimeRecorder(
#      68         conv_res, "pipeline_total", scope=ProfilingScope.DOCUMENT
#      69     ):
#      70         # These steps are building and assembling the structure of the
#      71         # output DoclingDocument.
# ---> 72         conv_res = self._build_document(conv_res)
#      73         conv_res = self._assemble_document(conv_res)
#      74         # From this stage, all operations should rely only on conv_res.output
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/pipeline/base_pipeline.py:230, in PaginatedPipeline._build_document(self, conv_res)
#     227 # 2. Run pipeline stages
#     228 pipeline_pages = self._apply_on_pages(conv_res, init_pages)
# --> 230 for p in pipeline_pages:  # Must exhaust!
#     231     # Cleanup cached images
#     232     if not self.keep_images:
#     233         p._image_cache = {}
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/pipeline/base_pipeline.py:195, in PaginatedPipeline._apply_on_pages(self, conv_res, page_batch)
#     192 for model in self.build_pipe:
#     193     page_batch = model(conv_res, page_batch)
# --> 195 yield from page_batch
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/models/page_assemble_model.py:70, in PageAssembleModel.__call__(self, conv_res, page_batch)
#      67 def __call__(
#      68     self, conv_res: ConversionResult, page_batch: Iterable[Page]
#      69 ) -> Iterable[Page]:
# ---> 70     for page in page_batch:
#      71         assert page._backend is not None
#      72         if not page._backend.is_valid():
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/models/table_structure_model.py:177, in TableStructureModel.__call__(self, conv_res, page_batch)
#     174     yield from page_batch
#     175     return
# --> 177 for page in page_batch:
#     178     assert page._backend is not None
#     179     if not page._backend.is_valid():
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/models/layout_model.py:152, in LayoutModel.__call__(self, conv_res, page_batch)
#     148 def __call__(
#     149     self, conv_res: ConversionResult, page_batch: Iterable[Page]
#     150 ) -> Iterable[Page]:
#     151     # Convert to list to allow multiple iterations
# --> 152     pages = list(page_batch)
#     154     # Separate valid and invalid pages
#     155     valid_pages = []
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/models/easyocr_model.py:160, in EasyOcrModel.__call__(self, conv_res, page_batch)
#     155     if self.options.suppress_mps_warnings:
#     156         warnings.filterwarnings(
#     157             "ignore", message=".*pin_memory.*MPS.*"
#     158         )
# --> 160     result = self.reader.readtext(im)
#     162 del high_res_image
#     163 del im
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/easyocr/easyocr.py:456, in Reader.readtext(self, image, decoder, beamWidth, batch_size, workers, allowlist, blocklist, detail, rotation_info, paragraph, min_size, contrast_ths, adjust_contrast, filter_ths, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, y_ths, x_ths, add_margin, threshold, bbox_min_score, bbox_min_size, max_candidates, output_format)
#     450 '''
#     451 Parameters:
#     452 image: file path or numpy-array or a byte stream object
#     453 '''
#     454 img, img_cv_grey = reformat_input(image)
# --> 456 horizontal_list, free_list = self.detect(img,
#     457                                          min_size = min_size, text_threshold = text_threshold,\
#     458                                          low_text = low_text, link_threshold = link_threshold,\
#     459                                          canvas_size = canvas_size, mag_ratio = mag_ratio,\
#     460                                          slope_ths = slope_ths, ycenter_ths = ycenter_ths,\
#     461                                          height_ths = height_ths, width_ths= width_ths,\
#     462                                          add_margin = add_margin, reformat = False,\
#     463                                          threshold = threshold, bbox_min_score = bbox_min_score,\
#     464                                          bbox_min_size = bbox_min_size, max_candidates = max_candidates
#     465                                          )
#     466 # get the 1st result from hor & free list as self.detect returns a list of depth 3
#     467 horizontal_list, free_list = horizontal_list[0], free_list[0]
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/easyocr/easyocr.py:321, in Reader.detect(self, img, min_size, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, add_margin, reformat, optimal_num_chars, threshold, bbox_min_score, bbox_min_size, max_candidates)
#     318 if reformat:
#     319     img, img_cv_grey = reformat_input(img)
# --> 321 text_box_list = self.get_textbox(self.detector,
#     322                             img,
#     323                             canvas_size = canvas_size,
#     324                             mag_ratio = mag_ratio,
#     325                             text_threshold = text_threshold,
#     326                             link_threshold = link_threshold,
#     327                             low_text = low_text,
#     328                             poly = False,
#     329                             device = self.device,
#     330                             optimal_num_chars = optimal_num_chars,
#     331                             threshold = threshold,
#     332                             bbox_min_score = bbox_min_score,
#     333                             bbox_min_size = bbox_min_size,
#     334                             max_candidates = max_candidates,
#     335                             )
#     337 horizontal_list_agg, free_list_agg = [], []
#     338 for text_box in text_box_list:
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/easyocr/detection.py:95, in get_textbox(detector, image, canvas_size, mag_ratio, text_threshold, link_threshold, low_text, poly, device, optimal_num_chars, **kwargs)
#      93 result = []
#      94 estimate_num_chars = optimal_num_chars is not None
# ---> 95 bboxes_list, polys_list = test_net(canvas_size, mag_ratio, detector,
#      96                                    image, text_threshold,
#      97                                    link_threshold, low_text, poly,
#      98                                    device, estimate_num_chars)
#      99 if estimate_num_chars:
#     100     polys_list = [[p for p, _ in sorted(polys, key=lambda x: abs(optimal_num_chars - x[1]))]
#     101                   for polys in polys_list]
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/easyocr/detection.py:46, in test_net(canvas_size, mag_ratio, net, image, text_threshold, link_threshold, low_text, poly, device, estimate_num_chars)
#      44 # forward pass
#      45 with torch.no_grad():
# ---> 46     y, feature = net(x)
#      48 boxes_list, polys_list = [], []
#      49 for out in y:
#      50     # make score and link map
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/easyocr/craft.py:60, in CRAFT.forward(self, x)
#      58 def forward(self, x):
#      59     """ Base network """
# ---> 60     sources = self.basenet(x)
#      62     """ U network """
#      63     y = torch.cat([sources[0], sources[1]], dim=1)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/easyocr/model/modules.py:74, in vgg16_bn.forward(self, X)
#      72 h = self.slice3(h)
#      73 h_relu4_3 = h
# ---> 74 h = self.slice4(h)
#      75 h_relu5_3 = h
#      76 h = self.slice5(h)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     246 """
#     247 Runs the forward pass.
#     248 """
#     249 for module in self:
# --> 250     input = module(input)
#     251 return input
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/conv.py:548, in Conv2d.forward(self, input)
#     547 def forward(self, input: Tensor) -> Tensor:
# --> 548     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/conv.py:543, in Conv2d._conv_forward(self, input, weight, bias)
#     531 if self.padding_mode != "zeros":
#     532     return F.conv2d(
#     533         F.pad(
#     534             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    541         self.groups,
#     542     )
# --> 543 return F.conv2d(
#     544     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545 )
#
# KeyboardInterrupt:

# %%
# Enable the profiling to measure the time spent
settings.debug.profile_pipeline_timings = True

# Convert the document
#result = doc_converter_global.convert(FIRST_10_PAGES)
#result = doc_converter_global.convert(SOURCE)
result = doc_converter_global.convert("/home/nurshed/Desktop/python/project/RAG Study/docling/KONE Sustainability_tcm117-105566.pdf")

output_dir.mkdir(parents=True, exist_ok=True)
#doc_filename = Path(FIRST_10_PAGES).stem
#doc_filename = Path(FIRST_10_PAGES).stem
doc_filename = Path("/home/nurshed/Desktop/python/project/RAG Study/docling/KONE Sustainability_tcm117-105566.pdf").stem

# Save markdown with embedded pictures
#md_filename = output_dir / f"{doc_filename}.md"
md_filename = output_dir / f"{doc_filename}-with-images.md"
#result.document.save_as_markdown(md_filename) # just shows there is image at this point, <!-- image -->
#result.document.save_as_markdown(md_filename, image_mode=ImageRefMode.EMBEDDED) # image is embedded with base64
result.document.save_as_markdown(md_filename, image_mode=ImageRefMode.REFERENCED) #artifacts folder is created with this

_log.info(f"Markdown content has been saved to {md_filename}")
# Out:
# 2025-10-23 17:16:11,637 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-23 17:16:11,687 - INFO - Going to convert document batch...
# 2025-10-23 17:16:11,688 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 6722b4d67bf82aafc8858d5663f840fd
# 2025-10-23 17:16:11,689 - INFO - Accelerator device: 'cpu'
# 2025-10-23 17:16:11,691 - WARNING - Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# 2025-10-23 17:17:01,135 - INFO - Download complete
# 2025-10-23 17:17:01,135 - WARNING - Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# 2025-10-23 17:17:04,473 - INFO - Download complete.
# 2025-10-23 17:17:06,588 - INFO - Accelerator device: 'cpu'
# 2025-10-23 17:17:08,240 - INFO - Accelerator device: 'cpu'
# 2025-10-23 17:17:08,758 - INFO - Processing document KONE Sustainability_tcm117-105566.pdf
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /home/nurshed/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 7
#       2 settings.debug.profile_pipeline_timings = True
#       4 # Convert the document
#       5 #result = doc_converter_global.convert(FIRST_10_PAGES)
#       6 #result = doc_converter_global.convert(SOURCE)
# ----> 7 result = doc_converter_global.convert("/home/nurshed/Desktop/python/project/RAG Study/docling/KONE Sustainability_tcm117-105566.pdf")
#       9 output_dir.mkdir(parents=True, exist_ok=True)
#      10 #doc_filename = Path(FIRST_10_PAGES).stem
#      11 #doc_filename = Path(FIRST_10_PAGES).stem
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/pydantic/_internal/_validate_call.py:39, in update_wrapper_attributes.<locals>.wrapper_function(*args, **kwargs)
#      37 @functools.wraps(wrapped)
#      38 def wrapper_function(*args, **kwargs):
# ---> 39     return wrapper(*args, **kwargs)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/pydantic/_internal/_validate_call.py:136, in ValidateCallWrapper.__call__(self, *args, **kwargs)
#     133 if not self.__pydantic_complete__:
#     134     self._create_validators()
# --> 136 res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#     137 if self.__return_pydantic_validator__:
#     138     return self.__return_pydantic_validator__(res)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/document_converter.py:245, in DocumentConverter.convert(self, source, headers, raises_on_error, max_num_pages, max_file_size, page_range)
#     227 @validate_call(config=ConfigDict(strict=True))
#     228 def convert(
#     229     self,
#    (...)    235     page_range: PageRange = DEFAULT_PAGE_RANGE,
#     236 ) -> ConversionResult:
#     237     all_res = self.convert_all(
#     238         source=[source],
#     239         raises_on_error=raises_on_error,
#    (...)    243         page_range=page_range,
#     244     )
# --> 245     return next(all_res)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/document_converter.py:268, in DocumentConverter.convert_all(self, source, headers, raises_on_error, max_num_pages, max_file_size, page_range)
#     265 conv_res_iter = self._convert(conv_input, raises_on_error=raises_on_error)
#     267 had_result = False
# --> 268 for conv_res in conv_res_iter:
#     269     had_result = True
#     270     if raises_on_error and conv_res.status not in {
#     271         ConversionStatus.SUCCESS,
#     272         ConversionStatus.PARTIAL_SUCCESS,
#     273     }:
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/document_converter.py:340, in DocumentConverter._convert(self, conv_input, raises_on_error)
#     338             yield item
#     339 else:
# --> 340     for item in map(
#     341         process_func,
#     342         input_batch,
#     343     ):
#     344         elapsed = time.monotonic() - start_time
#     345         start_time = time.monotonic()
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/document_converter.py:387, in DocumentConverter._process_document(self, in_doc, raises_on_error)
#     383 valid = (
#     384     self.allowed_formats is not None and in_doc.format in self.allowed_formats
#     385 )
#     386 if valid:
# --> 387     conv_res = self._execute_pipeline(in_doc, raises_on_error=raises_on_error)
#     388 else:
#     389     error_message = f"File format not allowed: {in_doc.file}"
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/document_converter.py:410, in DocumentConverter._execute_pipeline(self, in_doc, raises_on_error)
#     408 pipeline = self._get_pipeline(in_doc.format)
#     409 if pipeline is not None:
# --> 410     conv_res = pipeline.execute(in_doc, raises_on_error=raises_on_error)
#     411 else:
#     412     if raises_on_error:
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/pipeline/base_pipeline.py:72, in BasePipeline.execute(self, in_doc, raises_on_error)
#      66 try:
#      67     with TimeRecorder(
#      68         conv_res, "pipeline_total", scope=ProfilingScope.DOCUMENT
#      69     ):
#      70         # These steps are building and assembling the structure of the
#      71         # output DoclingDocument.
# ---> 72         conv_res = self._build_document(conv_res)
#      73         conv_res = self._assemble_document(conv_res)
#      74         # From this stage, all operations should rely only on conv_res.output
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/pipeline/base_pipeline.py:230, in PaginatedPipeline._build_document(self, conv_res)
#     227 # 2. Run pipeline stages
#     228 pipeline_pages = self._apply_on_pages(conv_res, init_pages)
# --> 230 for p in pipeline_pages:  # Must exhaust!
#     231     # Cleanup cached images
#     232     if not self.keep_images:
#     233         p._image_cache = {}
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/pipeline/base_pipeline.py:195, in PaginatedPipeline._apply_on_pages(self, conv_res, page_batch)
#     192 for model in self.build_pipe:
#     193     page_batch = model(conv_res, page_batch)
# --> 195 yield from page_batch
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/models/page_assemble_model.py:70, in PageAssembleModel.__call__(self, conv_res, page_batch)
#      67 def __call__(
#      68     self, conv_res: ConversionResult, page_batch: Iterable[Page]
#      69 ) -> Iterable[Page]:
# ---> 70     for page in page_batch:
#      71         assert page._backend is not None
#      72         if not page._backend.is_valid():
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/models/table_structure_model.py:177, in TableStructureModel.__call__(self, conv_res, page_batch)
#     174     yield from page_batch
#     175     return
# --> 177 for page in page_batch:
#     178     assert page._backend is not None
#     179     if not page._backend.is_valid():
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling/models/layout_model.py:174, in LayoutModel.__call__(self, conv_res, page_batch)
#     172 if valid_page_images:
#     173     with TimeRecorder(conv_res, "layout"):
# --> 174         batch_predictions = self.layout_predictor.predict_batch(  # type: ignore[attr-defined]
#     175             valid_page_images
#     176         )
#     178 # Process each page with its predictions
#     179 valid_page_idx = 0
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/docling_ibm_models/layoutmodel/layout_predictor.py:222, in LayoutPredictor.predict_batch(self, images)
#     218 # Process all images in a single batch
#     219 inputs = self._image_processor(images=pil_images, return_tensors="pt").to(
#     220     self._device
#     221 )
# --> 222 outputs = self._model(**inputs)
#     224 # Post-process all results at once
#     225 results_list: List[Dict[str, Tensor]] = (
#     226     self._image_processor.post_process_object_detection(
#     227         outputs,
#    (...)    230     )
#     231 )
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/transformers/models/rt_detr_v2/modeling_rt_detr_v2.py:1920, in RTDetrV2ForObjectDetection.forward(self, pixel_values, pixel_mask, encoder_outputs, inputs_embeds, decoder_inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, **kwargs)
#    1915 output_hidden_states = (
#    1916     output_hidden_states if output_hidden_states is not None else self.config.output_hidden_states
#    1917 )
#    1918 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1920 outputs = self.model(
#    1921     pixel_values,
#    1922     pixel_mask=pixel_mask,
#    1923     encoder_outputs=encoder_outputs,
#    1924     inputs_embeds=inputs_embeds,
#    1925     decoder_inputs_embeds=decoder_inputs_embeds,
#    1926     labels=labels,
#    1927     output_attentions=output_attentions,
#    1928     output_hidden_states=output_hidden_states,
#    1929     return_dict=return_dict,
#    1930 )
#    1932 denoising_meta_values = (
#    1933     outputs.denoising_meta_values if return_dict else outputs[-1] if self.training else None
#    1934 )
#    1936 outputs_class = outputs.intermediate_logits if return_dict else outputs[2]
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/transformers/models/rt_detr_v2/modeling_rt_detr_v2.py:1657, in RTDetrV2Model.forward(self, pixel_values, pixel_mask, encoder_outputs, inputs_embeds, decoder_inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1654 init_reference_points = reference_points_unact.detach()
#    1656 # decoder
# -> 1657 decoder_outputs = self.decoder(
#    1658     inputs_embeds=target,
#    1659     encoder_hidden_states=source_flatten,
#    1660     encoder_attention_mask=attention_mask,
#    1661     reference_points=init_reference_points,
#    1662     spatial_shapes=spatial_shapes,
#    1663     spatial_shapes_list=spatial_shapes_list,
#    1664     level_start_index=level_start_index,
#    1665     output_attentions=output_attentions,
#    1666     output_hidden_states=output_hidden_states,
#    1667     return_dict=return_dict,
#    1668 )
#    1670 if not return_dict:
#    1671     enc_outputs = tuple(
#    1672         value
#    1673         for value in [enc_topk_logits, enc_topk_bboxes, enc_outputs_class, enc_outputs_coord_logits]
#    1674         if value is not None
#    1675     )
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/transformers/models/rt_detr_v2/modeling_rt_detr_v2.py:652, in RTDetrV2Decoder.forward(self, inputs_embeds, encoder_hidden_states, encoder_attention_mask, position_embeddings, reference_points, spatial_shapes, spatial_shapes_list, level_start_index, valid_ratios, output_attentions, output_hidden_states, return_dict)
#     649 if output_hidden_states:
#     650     all_hidden_states += (hidden_states,)
# --> 652 layer_outputs = decoder_layer(
#     653     hidden_states,
#     654     position_embeddings=position_embeddings,
#     655     encoder_hidden_states=encoder_hidden_states,
#     656     reference_points=reference_points_input,
#     657     spatial_shapes=spatial_shapes,
#     658     spatial_shapes_list=spatial_shapes_list,
#     659     level_start_index=level_start_index,
#     660     encoder_attention_mask=encoder_attention_mask,
#     661     output_attentions=output_attentions,
#     662 )
#     664 hidden_states = layer_outputs[0]
#     666 # hack implementation for iterative bounding box refinement
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/transformers/models/rt_detr_v2/modeling_rt_detr_v2.py:404, in RTDetrV2DecoderLayer.forward(self, hidden_states, position_embeddings, reference_points, spatial_shapes, spatial_shapes_list, level_start_index, encoder_hidden_states, encoder_attention_mask, output_attentions)
#     401 residual = hidden_states
#     403 # Self Attention
# --> 404 hidden_states, self_attn_weights = self.self_attn(
#     405     hidden_states=hidden_states,
#     406     attention_mask=encoder_attention_mask,
#     407     position_embeddings=position_embeddings,
#     408     output_attentions=output_attentions,
#     409 )
#     411 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     412 hidden_states = residual + hidden_states
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/transformers/models/rt_detr_v2/modeling_rt_detr_v2.py:341, in RTDetrV2MultiheadAttention.forward(self, hidden_states, attention_mask, position_embeddings, output_attentions)
#     338 attn_output = attn_output.transpose(1, 2)
#     339 attn_output = attn_output.reshape(batch_size, target_len, embed_dim)
# --> 341 attn_output = self.out_proj(attn_output)
#     343 return attn_output, attn_weights_reshaped
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Desktop/python/venv/base/lib/python3.12/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
